# %%
import math
import numpy as np
from fill import fill_the_box, draw, rotate, place_box, get_scrap_vol

# %%
class Prisms:
    def __init__(self, code, size, quantity, roundingoff = 2):
        import math
        import numpy as np
        '''
        code: (str)
        size= ['bottom length', 'top length', 'width', 'heigth'] or size= ['length', 'width', 'heigth']
        bottom length > top length this is must
        quantity: (int)
        '''
        self.code = code
        self.quantity = quantity
        self.prism_left = quantity
        self.roundingoff = roundingoff
        if len(size) == 4:
            self.size = size
        elif len(size) == 3:
            self.size = [size[0]].extend(size)
        else:
            print('dimension of the prism is more then 4. But the code is written only for trapezodial prisms')

        self.bottom_length = self.size[0]
        self.top_length = self.size[1]
        self.width = self.size[2]
        self.height = self.size[3]
        self.angle = self.angle_from_height_length()

        self.volume = 0.5 * (self.bottom_length + self.top_length) * self.width* self.height
        
    def angle_from_height_length(self):
        height = self.height
        length = (self.bottom_length - self.top_length)/2
        angle_rad = math.atan(length / height)     # tan inverse in radians
        angle_deg = math.degrees(angle_rad)        # convert to degrees
        return np.round(angle_deg, self.roundingoff)

    def update_prism_left(self, used_quantity):
        self.prism_left = self.prism_left - used_quantity

    def get_volume(self):
        return self.volume

# %%
class Block:
    def __init__(self, unique_code, size, start_coord=[0,0,0]):
        self.unique_code = unique_code
        self.size = size
        self.start_coord = start_coord
        self.volume = size[0] * size[1] * size[2]
        self.place_box()

        self.scraps = []   # store Scrap objects

        self.prism_details = []
        self.all_prisms_coordinates = []

    def add_scrap(self, scrap_obj):
        scrap_obj.parent_block = self  # assign parent
        self.scraps.append(scrap_obj)

    def add_prisms_coordinates(self, prism, coordinates):
        prism_detail = {'prism': prism, 'coordinates': coordinates}
        self.prism_details.append(prism_detail)
        self.all_prisms_coordinates.extend(coordinates)

    def get_efficiency(self):
        prism_volume = 0
        for prism_detail in self.prism_details:
            prism_volume +=  prism_detail['prism'].volume*len(prism_detail['coordinates'])
        eff = (prism_volume/self.volume)*100
        #print('So the afficiency is: ', eff)
        return eff
            
    import itertools

    def can_fit_with_rotation(self, prism, rotation_axis = [[],['z'], ['z', 'x'], ['z', 'y'], ['x'], ['y']]):
        rotation_axis_new = []
        if prism.volume > self.volume:
            return False, rotation_axis_new
        for axis_order in rotation_axis:
            if len(axis_order) >0:
                rot = Rotation(axis_order=axis_order, pivot=self.start_coord)
                size = rot.get_new_lwh(self.size)
            else:
                size = self.size
            if (prism.bottom_length < size[0] and 
                prism.width < size[1] and
                    prism.height < size[2]):
                rotation_axis_new.append(axis_order)
        if len(rotation_axis_new) > 0:
            return True , rotation_axis_new
        else:
            return False, rotation_axis_new

    def place_box(self):
        length, width,  height = self.size[0], self.size[1], self.size[2] 
        [x, y, z] = self.start_coord
        #print('block: ',x,y,z,length, width, height)
        self.box_coordinate = [[x,y,z], [x+length,y,z], [x+length, y+width, z], [x, y+width, z], 
                                [x, y, z+height], [x+ length, y, z+height], [x+length, y+width, z+height], [x, y+ width, z+height]]

    def draw_it(self, only_scrap = False):
        big_block_coordinate = self.box_coordinate
        co_ordinates_list = self.all_prisms_coordinates
        scrap_volumes = []
        for scrap in self.scraps:
            scrap_volumes.append(scrap.box_coordinate)
        if only_scrap:
            draw(big_block_coordinate, co_ordinates_list=[], x_edges=[], y_edges=[], z_edges=[], 
                 planes={"xy_planes":[],"zx_planes":[],"yz_planes":[],}, scrap_volumes =scrap_volumes)
        else:
            draw(big_block_coordinate, co_ordinates_list, x_edges=[], y_edges=[], z_edges=[], 
                 planes={"xy_planes":[],"zx_planes":[],"yz_planes":[],}, scrap_volumes =[])



class Scrap(Block):
    def __init__(self, unique_code, size, start_coord):
        super().__init__(unique_code, size, start_coord)
        self.parent_block = None    # this will be assigned when added

    def delete_scrap(self):
        if self in self.parent_block.scraps:
            self.parent_block.scraps.remove(self)

# %%
class Rotation:
    def __init__(self, axis_order =['x', 'y'] ,pivot=(0,0,0) ,roundingoff =2):
        import numpy as np
       
        self.roundingoff = roundingoff
        self.axis_order = axis_order
        self.pivot = pivot


    def get_new_lwh(self, size ):
        size = size
        def get_lwh(axis, size):
            l , w, h = size
            if axis == 'z':
                l, w, h =w, l, h
            elif axis == 'y':
                l, w, h = h, w, l
            elif axis == 'x':
                l, w, h = l, h, w
            return [l,w,h]
        for axis in self.axis_order:
            size = get_lwh(axis, size)
        return size
       
    def get_starting_co_and_size(self, pts, after_rotation = True):
        '''
        at first rotate in order then give the starting co-ordinae and size.
        '''
        if after_rotation:
            pts = self.rotate_in_order( pts)
        pts = np.array(pts, dtype=float)
            
        
        #pts = np.array(cuboid_co)
        xs = pts[:,0]; ys = pts[:,1]; zs = pts[:,2]
        xmin, xmax = xs.min(), xs.max()
        ymin, ymax = ys.min(), ys.max()
        zmin, zmax = zs.min(), zs.max()
    
        starting_point = [xmin, ymin, zmin]
        size = [xmax - xmin, ymax - ymin, zmax - zmin]
    
        return starting_point, size
    def rotate_in_order(self, points):
        new_pts = points
        for axis in self.axis_order:
            new_pts = self.rotate(new_pts, 90, axis, self.pivot)
        return new_pts

    def rotate_in_reverse_order(self, points):
        new_pts = points
        for axis in reversed(self.axis_order):
            new_pts = self.rotate(new_pts, -90, axis, self.pivot)
        return new_pts
    def rotate(self, points, angle_deg, axis='z', pivot=(0, 0, 0)):
        """
        Rotate 3D point(s) around a chosen axis with an optional pivot.
        Using positive angle (+θ):
        Rotate around X-axis → rotation is counter-clockwise when looking from +X toward the origin
        Rotate around Y-axis → rotation is counter-clockwise when looking from +Y toward the origin
        Rotate around Z-axis → rotation is counter-clockwise when looking from +Z toward the origin
    
        points : (N,3) array or (3,) single point
        angle_deg : rotation angle in degrees
        axis : 'x', 'y', or 'z'
        pivot : point to rotate around (default = origin)
        """
        pts = np.array(points, dtype=float)
        if pts.ndim == 1:
            pts = pts.reshape(1, 3)
    
        angle = np.radians(angle_deg)
        px, py, pz = pivot
    
        # ---- Shift points so pivot becomes origin ----
        shifted = pts - np.array([px, py, pz])
    
        # ---- Rotation matrix for X, Y, or Z axis ----
        if axis == 'x':
            R = np.array([
                [1, 0, 0],
                [0, np.cos(angle), -np.sin(angle)],
                [0, np.sin(angle), np.cos(angle)]
            ])
        elif axis == 'y':
            R = np.array([
                [np.cos(angle), 0, np.sin(angle)],
                [0, 1, 0],
                [-np.sin(angle), 0, np.cos(angle)]
            ])
        elif axis == 'z':
            R = np.array([
                [np.cos(angle), -np.sin(angle), 0],
                [np.sin(angle),  np.cos(angle), 0],
                [0, 0, 1]
            ])
        else:
            raise ValueError("axis must be one of 'x', 'y', 'z'")
    
        # ---- Apply rotation ----
        rotated = shifted @ R.T
    
        # ---- Shift back to original pivot ----
        rounded = np.round(rotated + np.array([px, py, pz]), self.roundingoff)
        return rounded

# %%
class People_helper:
    def __init__(self, buffer =2, parent_block_sizes = [[1870,800, 350]]):
        
        self.all_scrap = []
        self.scrap_count = 0
        self.big_block_count = 0
        self.all_big_blocks = []
        self.rotation_axis = [[],['z'], ['z', 'x'], ['z', 'y'], ['x'], ['y']]

        
        self.buffer= buffer
        #self.Bigblock_size = Bigblock_size
        self.parent_block_sizes = parent_block_sizes

        self.all_scrap_temp = []

    def add_one_big_block(self, size, code='B'):
        self.big_block_count +=1
        origine = [0,0,0]
        starting_point = origine
        block = Block(code+str(self.big_block_count), size, start_coord=starting_point )
        self.all_big_blocks.append(block)

        ##print("new Blockl is created ",block.unique_code)

        return block
    def get_a_temp_block(self, size, code = 'Temp'):
        origine = [0,0,0]
        starting_point = origine
        block = Block(code, size, start_coord=starting_point )

        return block


    def try_to_pack_inside_all_scrap(self, prism, all_scrap = None):
        if all_scrap is None:
            all_scrap = self.all_scrap
        for scrap in all_scrap[:]:
            co_ordinates_list, big_block_coordinate, scrap_volumes, prism_count, scrap_blocks_list_temp = self.fill_the_prism_optimally(
                prism,scrap = scrap)
    def check_which_block_to_add(self, prism):
        size_list_global = []
        prism_count_list_global = []
        axis_order_list_global = []
        for parent_size in self.parent_block_sizes:
            size_list = []
            prism_count_list = []
            block = self.get_a_temp_block( parent_size, code = 'Temp')
            cond , rotation_axis_new = block.can_fit_with_rotation(prism,  self.rotation_axis)
            if not cond:
                continue
            for axis_order in rotation_axis_new:
                if len(axis_order) != 0:
                    rot = Rotation(axis_order=axis_order, pivot=block.start_coord)
                    size = rot.get_new_lwh(block.size)
                else:
                    size = block.size
                size_list.append(size)
            
                # pack it inside the block
                co_ordinates_list, big_block_coordinate, end_coordinates, prism_count = fill_the_box(prism, 
                                                                                                 Block_size =  size,
                                                                                                 starting_co = block.start_coord, 
                                                                                                 buffer = self.buffer)
                prism_count_list.append(prism_count)

            prism_count_max = max(prism_count_list)
            max_index = prism_count_list.index(prism_count_max)
            axis_order_max = rotation_axis_new[max_index]
            size_max = size_list[max_index]

            prism_count_list_global.append(prism_count_max)
            size_list_global.append(size_max)
            axis_order_list_global.append(axis_order_max)

        prism_count_global_max = max(prism_count_list_global)
        max_index = prism_count_list_global.index(prism_count_global_max)
        axis_order_max = axis_order_list_global[max_index]
        size_global_max = size_list_global[max_index]

        return self.parent_block_sizes[max_index]
               
                

    def fill_the_prism_optimally(self, prism, scrap):
        self.all_scrap_temp = []
        size_list = []
        prism_count_list = []
        cond , rotation_axis_new = scrap.can_fit_with_rotation(prism,  self.rotation_axis)
        if not cond:
            ##print('This prism ',prism.code, ' can not be fit inside block ', scrap.unique_code)
            return None, None, None, None, None
    
        for axis_order in rotation_axis_new:
            if len(axis_order) != 0:
                rot = Rotation(axis_order=axis_order, pivot=scrap.start_coord)
                size = rot.get_new_lwh(scrap.size)
            else:
                size = scrap.size
            size_list.append(size)
        
            # pack it inside the block
            co_ordinates_list, big_block_coordinate, end_coordinates, prism_count = fill_the_box(prism, 
                                                                                             Block_size =  size,
                                                                                             starting_co = scrap.start_coord, 
                                                                                             buffer = self.buffer)
            prism_count_list.append(prism_count)
            

        prism_count_max = max(prism_count_list)
        max_index = prism_count_list.index(prism_count_max)
        axis_order_max = rotation_axis_new[max_index]
        size_max = size_list[max_index]

        if prism_count_max == 0:
            ##print('No prism fit inside the ', scrap.unique_code, '. Because prism count is 0.')
            return None, None, None, None, None

      
        ##print('Maximum ', prism_count_max,'cab be filled in side the block ', scrap.unique_code, '. with the axis order ', axis_order_max)
        eff = (prism.volume*prism_count_max/scrap.volume)*100
        ##print('The efficiency till now is ', eff,'%')


         # get the rotation tools
        if len(axis_order_max) != 0:
            rot = Rotation(axis_order=axis_order_max, pivot=scrap.start_coord)
            new_starting_point, size = rot.get_starting_co_and_size(scrap.box_coordinate)
    
            # after rotation fill the block
            co_ordinates_list, big_block_coordinate, end_coordinates, prism_count = fill_the_box(prism, 
                                                                                             Block_size =  size_max,
                                                                                             starting_co = new_starting_point, 
                                                                                             buffer = self.buffer)
            scrap_volumes, scrap_Boxes_new =  get_scrap_vol(end_coordinates, size_max, new_starting_point)
    
    
            # Now rotate in the reverse direction
            co_ordinates_list = rot.rotate_in_reverse_order(co_ordinates_list).tolist()
            big_block_coordinate = rot.rotate_in_reverse_order(big_block_coordinate)
            scrap_volumes = rot.rotate_in_reverse_order(scrap_volumes)
        else:
            co_ordinates_list, big_block_coordinate, end_coordinates, prism_count = fill_the_box(prism, 
                                                                                             Block_size =  size_max,
                                                                                             starting_co = scrap.start_coord, 
                                                                                             buffer = self.buffer)
            scrap_volumes, scrap_Boxes_new =  get_scrap_vol(end_coordinates, size_max, scrap.start_coord, co_ordinates_list)
        

        assert prism_count >0

        if type(scrap) is Block:
            block = scrap
            
            prism.update_prism_left(prism_count)
            block.add_prisms_coordinates(prism, co_ordinates_list)
            scrap_blocks_list_temp = self.add_update_scrap_list(block, scrap_volumes)

            self.all_scrap_temp = scrap_blocks_list_temp

            
        elif type(scrap) is Scrap:
            block = scrap.parent_block
            
            prism.update_prism_left(prism_count)
            block.add_prisms_coordinates(prism, co_ordinates_list)
            scrap_blocks_list_temp = scrap_blocks_list_temp = self.add_update_scrap_list(block, scrap_volumes)

            self.delete_scrap(scrap)
        else:
            raise Exception('Scrap element inside fill_the_prism_optimally function must be a scrap or block')

        

        return co_ordinates_list, big_block_coordinate, scrap_volumes, prism_count, scrap_blocks_list_temp

    def is_small_size(self, size):
        volume = size[0]*size[1]*size[2]
        is_small_volume = volume < 10
        is_small_length = size[0] < 2 or size[1] < 2 or size[2] < 2

        return is_small_volume or is_small_length
    
    def add_update_scrap_list(self, block, scrap_volumes):
        scrap_blocks_list_temp = []
        for scrap_vol in scrap_volumes:
            self.scrap_count +=1
            rot = Rotation()
            #print(scrap_vol)
            scrap_starting_point, scrap_size = rot.get_starting_co_and_size(scrap_vol, after_rotation = False)

            if self.is_small_size(scrap_size):
                continue
            # add scrap element
            s = Scrap('s'+str(self.scrap_count), scrap_size, scrap_starting_point)
            block.add_scrap(s)

            # add scrap to emp scrap list.
            scrap_blocks_list_temp.append(s)   
            
        # sort low volume 1st inside the scrap elements
        scrap_blocks_list_temp = sorted(scrap_blocks_list_temp, key=lambda s: s.volume)

        # add temp scrap temp list to global scrap list
        self.all_scrap.extend(scrap_blocks_list_temp)

        return scrap_blocks_list_temp

    def delete_scrap(self,scrap):

        # remove it from global list
        ##print(scrap.unique_code,' is deleted')
        self.all_scrap.remove(scrap)
        scrap.delete_scrap()

# %%
'''def get_block_details(helper):
    block_details = {
        "Total_number_of_blocks": len(helper.all_big_blocks),
        "Total_eff": 0,
        "blocks": []
    }

    total_eff_sum = 0

    for block in helper.all_big_blocks:
        block_eff = round(block.get_efficiency(), 2)
        total_eff_sum += block_eff

        # Count prisms inside this block grouped by prism code
        prism_count_dict = {}   # { 'G14': 16, 'G15': 2 }

        for entry in block.prism_details:
            prism = entry['prism']
            coords = entry['coordinates']     # N coordinates = N prisms
            count = len(coords)

            if prism.code not in prism_count_dict:
                prism_count_dict[prism.code] = 0
            prism_count_dict[prism.code] += count

        # Convert dict → required list format
        prism_list = []
        for code, num in prism_count_dict.items():
            prism_list.append({"code": code, "number": num})

        block_details["blocks"].append({
            "code": block.unique_code,
            "eff": block_eff,
            "prisms": prism_list
        })

    # Total efficiency = average block efficiency
    if len(helper.all_big_blocks) > 0:
        block_details["Total_eff"] = round(total_eff_sum / len(helper.all_big_blocks), 2)
    else:
        block_details["Total_eff"] = 0

    return block_details'''
def get_block_details(helper):
    block_details = {
        "Total_number_of_blocks": len(helper.all_big_blocks),
        "Total_eff": 0,
        "blocks": [],
        "scraps": []
    }

    total_eff_sum = 0

    # ---- PROCESS ALL BLOCKS ----
    for block in helper.all_big_blocks:
        block_eff = round(block.get_efficiency(), 2)
        total_eff_sum += block_eff

        # Count prisms inside this block grouped by prism code
        prism_count_dict = {}   # { 'G14': 16, 'G15': 2 }

        for entry in block.prism_details:
            prism = entry['prism']
            count = len(entry['coordinates'])

            if prism.code not in prism_count_dict:
                prism_count_dict[prism.code] = 0
            prism_count_dict[prism.code] += count

        # Convert to required list format
        prism_list = [
            {"code": code, "number": num}
            for code, num in prism_count_dict.items()
        ]

        block_details["blocks"].append({
            "code": block.unique_code,
            "eff": block_eff,
            "prisms": prism_list
        })

    # ---- COMPUTE TOTAL EFFICIENCY ----
    if len(helper.all_big_blocks) > 0:
        block_details["Total_eff"] = round(total_eff_sum / len(helper.all_big_blocks), 2)
    else:
        block_details["Total_eff"] = 0


    # ---- ADD ALL SCRAPS ----
    for scrap in helper.all_scrap:
        block_details["scraps"].append({
            "code": scrap.unique_code,
            "size": scrap.size,
            "volume": scrap.volume
        })

    return block_details

# %%
def run_final_code(all_prisms, buffer = 2, parent_block_sizes = [[2000,800,400], [2000,500,500]] ):
    helper = People_helper(buffer, parent_block_sizes)
    for prism in all_prisms[:]:
        ##print('_______________________',prism.code,'__________________________')
        helper.try_to_pack_inside_all_scrap(prism)
        while True:
            if prism.prism_left == 0:
                ##print('-----------------------Break------------------------------')
                break
            # create a block
            size = helper.check_which_block_to_add( prism)
            b = helper.add_one_big_block(size)
            #cond = b is Block
            #print('cond: ', cond)
            co_ordinates_list, big_block_coordinate, scrap_volumes, prism_count , scrap_blocks_list_temp= helper.fill_the_prism_optimally(
                prism, b)
            helper.try_to_pack_inside_all_scrap(prism, scrap_blocks_list_temp)
    return helper

# %%
import pandas as pd
df = pd.read_excel("prism_data.xlsx")

# ---------- 2. DELETE Volume and AD ----------
#df = df.drop(columns=["Volume", "AD", '(α)', 'UW-(Kg)', 'C(angle)'])
#df

# %%
# ---------- 5. LOOP & CREATE OBJECTS ----------
def get_all_prisms():
    all_prisms = []
    for _, row in df.iterrows():
        size = [
            row["Bottom Length"],
            row["Top Length"],
            row["Width"],
            row["Height"]
        ]
    
        prism_obj = Prisms(row["MARK"], size, int(row["Nos"]))
        all_prisms.append(prism_obj)
    return all_prisms

# %%
tried = 0 # fixed
max_try = 5 # fixed
prism_list_sorted = sorted(all_prisms, key=lambda p: p.get_volume(), reverse=True) 
parent_block_sizes = [[1870,800, 350], [2000, 800,400]]
buffer = 2
while tried < max_try:
    try:
        all_prisms = get_all_prisms()
        helper = run_final_code(prism_list_sorted,buffer = buffer, parent_block_sizes = parent_block_sizes)
        block_details = get_block_details(helper)
        if block_details is not None and helper is not None:
            break
        tried +=1
    except:
        tried +=1

# %%
block_details
# Out:
# [{'code': 's3',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(350.0)],
#   'volume': np.float64(51407265.0)},
#  {'code': 's5',
#   'size': [np.float64(131.80000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(21467584.00000003)},
#  {'code': 's6',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's9',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's7',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's12',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's11',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(32171854.0)},
#  {'code': 's15',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(350.0)],
#   'volume': np.float64(51407265.0)},
#  {'code': 's18',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's16',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's20',
#   'size': [np.float64(131.80000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(21467584.00000003)},
#  {'code': 's21',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's23',
#   'size': [np.float64(131.80000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(21467584.00000003)},
#  {'code': 's24',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's27',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's26',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(32171854.0)},
#  {'code': 's30',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's29',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(32171854.0)},
#  {'code': 's33',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's32',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(32171854.0)},
#  {'code': 's36',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's39',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's38',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(32171854.0)},
#  {'code': 's42',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's45',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's43',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's48',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's47',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(32171854.0)},
#  {'code': 's49',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's52',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's57',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's60',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's63',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(350.0)],
#   'volume': np.float64(51407265.0)},
#  {'code': 's66',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's69',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(350.0)],
#   'volume': np.float64(51407265.0)},
#  {'code': 's72',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(84.5),
#    np.float64(203.6)],
#   'volume': np.float64(29904340.439999998)},
#  {'code': 's75',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's73',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's78',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's76',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's81',
#   'size': [np.float64(131.80000000000018),
#    np.float64(715.5),
#    np.float64(203.6)],
#   'volume': np.float64(19200070.440000024)},
#  {'code': 's79',
#   'size': [np.float64(1870.0), np.float64(84.5), np.float64(350.0)],
#   'volume': np.float64(55305250.0)},
#  {'code': 's84',
#   'size': [np.float64(1167.8), np.float64(84.5), np.float64(203.6)],
#   'volume': np.float64(20091064.759999998)},
#  {'code': 's87',
#   'size': [np.float64(104.80000000000018),
#    np.float64(660.6),
#    np.float64(203.6)],
#   'volume': np.float64(14095407.168000024)},
#  {'code': 's85',
#   'size': [np.float64(702.2),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(19929728.047999997)},
#  {'code': 's93',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's95',
#   'size': [np.float64(127.69999999999982),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(20799775.99999997)},
#  {'code': 's96',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's99',
#   'size': [np.float64(127.69999999999982),
#    np.float64(660.6),
#    np.float64(203.6)],
#   'volume': np.float64(17175415.031999975)},
#  {'code': 's98',
#   'size': [np.float64(1870.0),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(53074040.79999999)},
#  {'code': 's101',
#   'size': [np.float64(127.69999999999982),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(20799775.99999997)},
#  {'code': 's102',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's105',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's107',
#   'size': [np.float64(127.69999999999982),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(20799775.99999997)},
#  {'code': 's108',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's114',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's117',
#   'size': [np.float64(127.69999999999982),
#    np.float64(660.6),
#    np.float64(203.6)],
#   'volume': np.float64(17175415.031999975)},
#  {'code': 's123',
#   'size': [np.float64(127.69999999999982),
#    np.float64(660.6),
#    np.float64(203.6)],
#   'volume': np.float64(17175415.031999975)},
#  {'code': 's122',
#   'size': [np.float64(1870.0),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(53074040.79999999)},
#  {'code': 's132',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's135',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's137',
#   'size': [np.float64(127.69999999999982),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(20799775.99999997)},
#  {'code': 's138',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's141',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's144',
#   'size': [np.float64(127.69999999999982),
#    np.float64(660.6),
#    np.float64(203.6)],
#   'volume': np.float64(17175415.031999975)},
#  {'code': 's156',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's159',
#   'size': [np.float64(127.69999999999982),
#    np.float64(660.6),
#    np.float64(203.6)],
#   'volume': np.float64(17175415.031999975)},
#  {'code': 's158',
#   'size': [np.float64(1870.0),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(53074040.79999999)},
#  {'code': 's161',
#   'size': [np.float64(127.69999999999982),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(20799775.99999997)},
#  {'code': 's162',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's168',
#   'size': [np.float64(1742.3000000000002),
#    np.float64(139.39999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(49449679.831999995)},
#  {'code': 's173',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(20960755.200000014)},
#  {'code': 's172',
#   'size': [np.float64(1870.0),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(24534399.999999966)},
#  {'code': 's177',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(19439699.328000017)},
#  {'code': 's176',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(22754015.999999974)},
#  {'code': 's180',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(19439699.328000017)},
#  {'code': 's178',
#   'size': [np.float64(1870.0),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(24534399.999999966)},
#  {'code': 's182',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(21798347.32799997)},
#  {'code': 's181',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(21991200.000000015)},
#  {'code': 's186',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(19439699.328000017)},
#  {'code': 's184',
#   'size': [np.float64(1870.0),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(24534399.999999966)},
#  {'code': 's187',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(21991200.000000015)},
#  {'code': 's188',
#   'size': [np.float64(1870.0),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(23503955.199999966)},
#  {'code': 's192',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(19439699.328000017)},
#  {'code': 's191',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(22754015.999999974)},
#  {'code': 's195',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(20395368.000000015)},
#  {'code': 's194',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(21798347.32799997)},
#  {'code': 's197',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(20960755.200000014)},
#  {'code': 's196',
#   'size': [np.float64(1870.0),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(24534399.999999966)},
#  {'code': 's201',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(20395368.000000015)},
#  {'code': 's200',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(21798347.32799997)},
#  {'code': 's202',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(21991200.000000015)},
#  {'code': 's203',
#   'size': [np.float64(1870.0),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(23503955.199999966)},
#  {'code': 's207',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(33.60000000000002),
#    np.float64(333.6)],
#   'volume': np.float64(19439699.328000017)},
#  {'code': 's206',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(800.0),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(22754015.999999974)},
#  {'code': 's209',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(21798347.32799997)},
#  {'code': 's208',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(21991200.000000015)},
#  {'code': 's214',
#   'size': [np.float64(1734.3000000000002),
#    np.float64(766.4),
#    np.float64(16.399999999999977)],
#   'volume': np.float64(21798347.32799997)},
#  {'code': 's211',
#   'size': [np.float64(1870.0),
#    np.float64(33.60000000000002),
#    np.float64(350.0)],
#   'volume': np.float64(21991200.000000015)},
#  {'code': 's218',
#   'size': [np.float64(597.4000000000001),
#    np.float64(54.89999999999998),
#    np.float64(203.6)],
#   'volume': np.float64(6677522.135999999)},
#  {'code': 's217',
#   'size': [np.float64(102.75), np.float64(660.6), np.float64(203.6)],
#   'volume': np.float64(13819685.940000001)},
#  {'code': 's221',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's223',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's224',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's226',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's227',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's236',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's235',
#   'size': [np.float64(1870.0),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(73976227.59999998)},
#  {'code': 's245',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's244',
#   'size': [np.float64(1870.0),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(73976227.59999998)},
#  {'code': 's248',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's256',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's257',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's259',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's260',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's263',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's262',
#   'size': [np.float64(1870.0),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(73976227.59999998)},
#  {'code': 's269',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's272',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's274',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's275',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's278',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's283',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's284',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's286',
#   'size': [np.float64(123.5), np.float64(800.0), np.float64(203.6)],
#   'volume': np.float64(20115680.0)},
#  {'code': 's287',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's290',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's296',
#   'size': [np.float64(1746.5),
#    np.float64(194.29999999999995),
#    np.float64(203.6)],
#   'volume': np.float64(69090631.81999998)},
#  {'code': 's299',
#   'size': [np.float64(123.5), np.float64(605.7), np.float64(203.6)],
#   'volume': np.float64(15230084.220000003)},
#  {'code': 's305',
#   'size': [np.float64(98.55000000000018),
#    np.float64(550.7),
#    np.float64(350.0)],
#   'volume': np.float64(18995019.750000037)},
#  {'code': 's310',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's313',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's316',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's320',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(203.6)],
#   'volume': np.float64(13376216.636000022)},
#  {'code': 's331',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's338',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(203.6)],
#   'volume': np.float64(13376216.636000022)},
#  {'code': 's344',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(350.0)],
#   'volume': np.float64(22994478.500000037)},
#  {'code': 's347',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(350.0)],
#   'volume': np.float64(22994478.500000037)},
#  {'code': 's352',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's356',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(203.6)],
#   'volume': np.float64(13376216.636000022)},
#  {'code': 's359',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(350.0)],
#   'volume': np.float64(22994478.500000037)},
#  {'code': 's361',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's368',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(350.0)],
#   'volume': np.float64(22994478.500000037)},
#  {'code': 's370',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's374',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(203.6)],
#   'volume': np.float64(13376216.636000022)},
#  {'code': 's377',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(350.0)],
#   'volume': np.float64(22994478.500000037)},
#  {'code': 's380',
#   'size': [np.float64(119.30000000000018),
#    np.float64(550.7),
#    np.float64(203.6)],
#   'volume': np.float64(13376216.636000022)},
#  {'code': 's382',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's385',
#   'size': [np.float64(119.30000000000018),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(19431584.00000003)},
#  {'code': 's392',
#   'size': [np.float64(96.5), np.float64(495.8), np.float64(203.6)],
#   'volume': np.float64(9741180.92)},
#  {'code': 's395',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's394',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's397',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(2736383.9999999925)},
#  {'code': 's398',
#   'size': [np.float64(1983.2), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(81805730.752)},
#  {'code': 's399',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(400.0)],
#   'volume': np.float64(5375999.999999985)},
#  {'code': 's404',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's403',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's405',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(400.0)],
#   'volume': np.float64(5375999.999999985)},
#  {'code': 's407',
#   'size': [np.float64(1983.2), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(81805730.752)},
#  {'code': 's410',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(400.0)],
#   'volume': np.float64(4014527.999999989)},
#  {'code': 's411',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(400.0)],
#   'volume': np.float64(5375999.999999985)},
#  {'code': 's414',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(400.0)],
#   'volume': np.float64(5375999.999999985)},
#  {'code': 's416',
#   'size': [np.float64(1983.2), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(81805730.752)},
#  {'code': 's418',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(2736383.9999999925)},
#  {'code': 's419',
#   'size': [np.float64(1983.2), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(81805730.752)},
#  {'code': 's422',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's425',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's424',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's428',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's427',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's430',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(2736383.9999999925)},
#  {'code': 's431',
#   'size': [np.float64(1983.2), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(81805730.752)},
#  {'code': 's432',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(400.0)],
#   'volume': np.float64(5375999.999999985)},
#  {'code': 's434',
#   'size': [np.float64(1983.2), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(81805730.752)},
#  {'code': 's437',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's436',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's440',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(400.0)],
#   'volume': np.float64(4014527.999999989)},
#  {'code': 's443',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(400.0)],
#   'volume': np.float64(4014527.999999989)},
#  {'code': 's446',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's445',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's449',
#   'size': [np.float64(16.799999999999955),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(2043394.7519999943)},
#  {'code': 's448',
#   'size': [np.float64(2000.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(82498720.0)},
#  {'code': 's450',
#   'size': [np.float64(16.799999999999955),
#    np.float64(800.0),
#    np.float64(400.0)],
#   'volume': np.float64(5375999.999999985)},
#  {'code': 's458',
#   'size': [np.float64(94.40000000000009),
#    np.float64(440.9),
#    np.float64(203.6)],
#   'volume': np.float64(8474027.456000008)},
#  {'code': 's461',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's464',
#   'size': [np.float64(106.40000000000009),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(12941500.09600001)},
#  {'code': 's463',
#   'size': [np.float64(1870.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(77136303.2)},
#  {'code': 's466',
#   'size': [np.float64(106.40000000000009),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(17330432.000000015)},
#  {'code': 's467',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's469',
#   'size': [np.float64(106.40000000000009),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(17330432.000000015)},
#  {'code': 's470',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's479',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's482',
#   'size': [np.float64(106.40000000000009),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(12941500.09600001)},
#  {'code': 's485',
#   'size': [np.float64(106.40000000000009),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(12941500.09600001)},
#  {'code': 's484',
#   'size': [np.float64(1870.0), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(77136303.2)},
#  {'code': 's488',
#   'size': [np.float64(106.40000000000009),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(12941500.09600001)},
#  {'code': 's493',
#   'size': [np.float64(106.40000000000009),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(17330432.000000015)},
#  {'code': 's494',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's497',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's499',
#   'size': [np.float64(106.40000000000009),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(17330432.000000015)},
#  {'code': 's500',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's503',
#   'size': [np.float64(106.40000000000009),
#    np.float64(597.4),
#    np.float64(203.6)],
#   'volume': np.float64(12941500.09600001)},
#  {'code': 's506',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's509',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's511',
#   'size': [np.float64(106.40000000000009),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(17330432.000000015)},
#  {'code': 's512',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's515',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's518',
#   'size': [np.float64(1763.6), np.float64(202.6), np.float64(203.6)],
#   'volume': np.float64(72747371.29599999)},
#  {'code': 's524',
#   'size': [np.float64(89.90000000000009),
#    np.float64(430.7),
#    np.float64(350.0)],
#   'volume': np.float64(13551975.500000013)},
#  {'code': 's527',
#   'size': [np.float64(1722.8), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(69485968.048)},
#  {'code': 's533',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's532',
#   'size': [np.float64(1870.0), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(75423009.2)},
#  {'code': 's542',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's551',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's560',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's566',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's565',
#   'size': [np.float64(1870.0), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(75423009.2)},
#  {'code': 's569',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's568',
#   'size': [np.float64(1870.0), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(75423009.2)},
#  {'code': 's572',
#   'size': [np.float64(1722.8), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(69485968.048)},
#  {'code': 's578',
#   'size': [np.float64(147.20000000000005),
#    np.float64(601.9),
#    np.float64(203.6)],
#   'volume': np.float64(18038894.848000005)},
#  {'code': 's577',
#   'size': [np.float64(1870.0), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(75423009.2)},
#  {'code': 's581',
#   'size': [np.float64(1722.8), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(69485968.048)},
#  {'code': 's584',
#   'size': [np.float64(1722.8), np.float64(198.1), np.float64(203.6)],
#   'volume': np.float64(69485968.048)},
#  {'code': 's587',
#   'size': [np.float64(96.40000000000009),
#    np.float64(430.7),
#    np.float64(350.0)],
#   'volume': np.float64(14531818.000000013)},
#  {'code': 's590',
#   'size': [np.float64(1722.4), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(69855583.488)},
#  {'code': 's593',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's595',
#   'size': [np.float64(147.5999999999999),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(24041087.999999985)},
#  {'code': 's596',
#   'size': [np.float64(1722.4), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(69855583.488)},
#  {'code': 's598',
#   'size': [np.float64(147.5999999999999),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(24041087.999999985)},
#  {'code': 's599',
#   'size': [np.float64(1722.4), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(69855583.488)},
#  {'code': 's608',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's607',
#   'size': [np.float64(1870.0), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(75841814.39999999)},
#  {'code': 's611',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's614',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's613',
#   'size': [np.float64(1870.0), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(75841814.39999999)},
#  {'code': 's617',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's626',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's632',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's635',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's638',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's644',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's643',
#   'size': [np.float64(1870.0), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(75841814.39999999)},
#  {'code': 's647',
#   'size': [np.float64(147.5999999999999),
#    np.float64(600.8),
#    np.float64(203.6)],
#   'volume': np.float64(18054857.08799999)},
#  {'code': 's646',
#   'size': [np.float64(1870.0), np.float64(199.2), np.float64(203.6)],
#   'volume': np.float64(75841814.39999999)},
#  {'code': 's662',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's667',
#   'size': [np.float64(146.79999999999995),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23910783.999999993)},
#  {'code': 's668',
#   'size': [np.float64(1723.2), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(70554631.87200001)},
#  {'code': 's674',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's680',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's679',
#   'size': [np.float64(1870.0), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(76565205.2)},
#  {'code': 's683',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's688',
#   'size': [np.float64(146.79999999999995),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23910783.999999993)},
#  {'code': 's689',
#   'size': [np.float64(1723.2), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(70554631.87200001)},
#  {'code': 's692',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's691',
#   'size': [np.float64(1870.0), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(76565205.2)},
#  {'code': 's698',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's697',
#   'size': [np.float64(1870.0), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(76565205.2)},
#  {'code': 's704',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's703',
#   'size': [np.float64(1870.0), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(76565205.2)},
#  {'code': 's707',
#   'size': [np.float64(146.79999999999995),
#    np.float64(598.9),
#    np.float64(203.6)],
#   'volume': np.float64(17900210.671999995)},
#  {'code': 's706',
#   'size': [np.float64(1870.0), np.float64(201.1), np.float64(203.6)],
#   'volume': np.float64(76565205.2)},
#  {'code': 's717',
#   'size': [np.float64(90.25000000000023),
#    np.float64(430.8),
#    np.float64(203.6)],
#   'volume': np.float64(7915906.9200000195)},
#  {'code': 's725',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's727',
#   'size': [np.float64(147.20000000000005),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23975936.000000004)},
#  {'code': 's728',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's734',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's733',
#   'size': [np.float64(1870.0), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(76984010.39999999)},
#  {'code': 's736',
#   'size': [np.float64(147.20000000000005),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23975936.000000004)},
#  {'code': 's737',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's739',
#   'size': [np.float64(147.20000000000005),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23975936.000000004)},
#  {'code': 's740',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's743',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's742',
#   'size': [np.float64(1870.0), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(76984010.39999999)},
#  {'code': 's746',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's745',
#   'size': [np.float64(1870.0), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(76984010.39999999)},
#  {'code': 's752',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's754',
#   'size': [np.float64(147.20000000000005),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23975936.000000004)},
#  {'code': 's755',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's767',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's766',
#   'size': [np.float64(1870.0), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(76984010.39999999)},
#  {'code': 's769',
#   'size': [np.float64(147.20000000000005),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23975936.000000004)},
#  {'code': 's770',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's773',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's776',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's779',
#   'size': [np.float64(1722.8), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(70924092.57599999)},
#  {'code': 's782',
#   'size': [np.float64(147.20000000000005),
#    np.float64(597.8),
#    np.float64(203.6)],
#   'volume': np.float64(17916018.176000003)},
#  {'code': 's781',
#   'size': [np.float64(1870.0), np.float64(202.2), np.float64(203.6)],
#   'volume': np.float64(76984010.39999999)},
#  {'code': 's791',
#   'size': [np.float64(146.4000000000001),
#    np.float64(596.0),
#    np.float64(203.6)],
#   'volume': np.float64(17764995.84000001)},
#  {'code': 's790',
#   'size': [np.float64(1870.0), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(77669328.0)},
#  {'code': 's794',
#   'size': [np.float64(146.4000000000001),
#    np.float64(596.0),
#    np.float64(203.6)],
#   'volume': np.float64(17764995.84000001)},
#  {'code': 's800',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's805',
#   'size': [np.float64(146.4000000000001),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23845632.000000015)},
#  {'code': 's806',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's817',
#   'size': [np.float64(146.4000000000001),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23845632.000000015)},
#  {'code': 's818',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's821',
#   'size': [np.float64(146.4000000000001),
#    np.float64(596.0),
#    np.float64(203.6)],
#   'volume': np.float64(17764995.84000001)},
#  {'code': 's824',
#   'size': [np.float64(146.4000000000001),
#    np.float64(596.0),
#    np.float64(203.6)],
#   'volume': np.float64(17764995.84000001)},
#  {'code': 's827',
#   'size': [np.float64(146.4000000000001),
#    np.float64(596.0),
#    np.float64(203.6)],
#   'volume': np.float64(17764995.84000001)},
#  {'code': 's826',
#   'size': [np.float64(1870.0), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(77669328.0)},
#  {'code': 's830',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's833',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's838',
#   'size': [np.float64(146.4000000000001),
#    np.float64(800.0),
#    np.float64(203.6)],
#   'volume': np.float64(23845632.000000015)},
#  {'code': 's839',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's842',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's845',
#   'size': [np.float64(1723.6), np.float64(204.0), np.float64(203.6)],
#   'volume': np.float64(71588691.83999999)},
#  {'code': 's851',
#   'size': [np.float64(218.4000000000001), np.float64(597.4), np.float64(76.6)],
#   'volume': np.float64(9994167.456000002)},
#  {'code': 's849',
#   'size': [np.float64(1738.2), np.float64(118.1), np.float64(146.4)],
#   'volume': np.float64(30053199.888)},
#  {'code': 's854',
#   'size': [np.float64(1734.8000000000002),
#    np.float64(40.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(10184386.272000005)},
#  {'code': 's852',
#   'size': [np.float64(135.19999999999982),
#    np.float64(800.0),
#    np.float64(146.4)],
#   'volume': np.float64(15834623.99999998)},
#  {'code': 's857',
#   'size': [np.float64(350.20000000000005),
#    np.float64(597.4),
#    np.float64(76.6)],
#   'volume': np.float64(16025446.168)},
#  {'code': 's855',
#   'size': [np.float64(1870.0), np.float64(118.1), np.float64(146.4)],
#   'volume': np.float64(32332000.8)},
#  {'code': 's858',
#   'size': [np.float64(1870.0),
#    np.float64(40.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(10978096.800000006)},
#  {'code': 's860',
#   'size': [np.float64(135.19999999999982),
#    np.float64(759.9),
#    np.float64(146.4)],
#   'volume': np.float64(15040913.47199998)},
#  {'code': 's861',
#   'size': [np.float64(218.4000000000001),
#    np.float64(715.5),
#    np.float64(146.4)],
#   'volume': np.float64(22877225.280000012)},
#  {'code': 's863',
#   'size': [np.float64(1519.8), np.float64(118.1), np.float64(146.4)],
#   'volume': np.float64(26277098.832)},
#  {'code': 's866',
#   'size': [np.float64(350.20000000000005),
#    np.float64(597.4),
#    np.float64(76.6)],
#   'volume': np.float64(16025446.168)},
#  {'code': 's865',
#   'size': [np.float64(1870.0), np.float64(118.1), np.float64(76.6)],
#   'volume': np.float64(16916880.2)},
#  {'code': 's868',
#   'size': [np.float64(1870.0),
#    np.float64(40.10000000000002),
#    np.float64(76.6)],
#   'volume': np.float64(5744004.200000003)},
#  {'code': 's869',
#   'size': [np.float64(135.19999999999982),
#    np.float64(759.9),
#    np.float64(76.6)],
#   'volume': np.float64(7869767.567999989)},
#  {'code': 's872',
#   'size': [np.float64(1734.8000000000002),
#    np.float64(40.10000000000002),
#    np.float64(76.6)],
#   'volume': np.float64(5328715.768000003)},
#  {'code': 's871',
#   'size': [np.float64(135.19999999999982),
#    np.float64(800.0),
#    np.float64(76.6)],
#   'volume': np.float64(8285055.999999988)},
#  {'code': 's873',
#   'size': [np.float64(1870.0),
#    np.float64(40.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(10978096.800000006)},
#  {'code': 's875',
#   'size': [np.float64(135.19999999999982),
#    np.float64(759.9),
#    np.float64(146.4)],
#   'volume': np.float64(15040913.47199998)},
#  {'code': 's878',
#   'size': [np.float64(1734.8000000000002),
#    np.float64(40.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(10184386.272000005)},
#  {'code': 's876',
#   'size': [np.float64(135.19999999999982),
#    np.float64(800.0),
#    np.float64(146.4)],
#   'volume': np.float64(15834623.99999998)},
#  {'code': 's880',
#   'size': [np.float64(1870.0),
#    np.float64(40.10000000000002),
#    np.float64(76.6)],
#   'volume': np.float64(5744004.200000003)},
#  {'code': 's881',
#   'size': [np.float64(135.19999999999982),
#    np.float64(759.9),
#    np.float64(76.6)],
#   'volume': np.float64(7869767.567999989)},
#  {'code': 's884',
#   'size': [np.float64(3.399999999999636), np.float64(759.9), np.float64(76.6)],
#   'volume': np.float64(197908.35599997878)},
#  {'code': 's882',
#   'size': [np.float64(1738.1999999999998),
#    np.float64(40.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(10204346.448000006)},
#  {'code': 's887',
#   'size': [np.float64(1734.8000000000002),
#    np.float64(40.10000000000002),
#    np.float64(76.6)],
#   'volume': np.float64(5328715.768000003)},
#  {'code': 's885',
#   'size': [np.float64(135.19999999999982),
#    np.float64(800.0),
#    np.float64(146.4)],
#   'volume': np.float64(15834623.99999998)},
#  {'code': 's889',
#   'size': [np.float64(3.399999999999636), np.float64(800.0), np.float64(76.6)],
# ...
#  {'code': 's1565',
#   'size': [np.float64(1767.6),
#    np.float64(800.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(9615744.000000017)},
#  {'code': 's1564',
#   'size': [np.float64(102.40000000000009),
#    np.float64(800.0),
#    np.float64(146.4)],
#   'volume': np.float64(11993088.000000011)},
#  {'code': 's1566',
#   'size': [np.float64(1767.6), np.float64(199.6), np.float64(139.6)],
#   'volume': np.float64(49252689.21599999)},
#  {'code': 's1567',
#   'size': [np.float64(1723.6),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(6985406.080000011)},
#  {'code': 's1569',
#   'size': [np.float64(539.0999999999999),
#    np.float64(441.9),
#    np.float64(139.6)],
#   'volume': np.float64(33256669.28399999)},
#  {'code': 's1568',
#   'size': [np.float64(1723.6),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(37078703.696)},
#  {'code': 's1571',
#   'size': [np.float64(1184.5),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(4800541.600000008)},
#  {'code': 's1572',
#   'size': [np.float64(1184.5),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(25481390.420000006)},
#  {'code': 's1574',
#   'size': [np.float64(1870.0),
#    np.float64(441.9),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(5619200.40000001)},
#  {'code': 's1575',
#   'size': [np.float64(101.40000000000009),
#    np.float64(441.9),
#    np.float64(139.6)],
#   'volume': np.float64(6255288.936000005)},
#  {'code': 's1579',
#   'size': [np.float64(103.40000000000009),
#    np.float64(441.9),
#    np.float64(139.6)],
#   'volume': np.float64(6378667.416000005)},
#  {'code': 's1577',
#   'size': [np.float64(1870.0),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(7578736.000000013)},
#  {'code': 's1578',
#   'size': [np.float64(1870.0),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(40228113.2)},
#  {'code': 's1581',
#   'size': [np.float64(1183.1),
#    np.float64(441.9),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(3555120.8520000055)},
#  {'code': 's1582',
#   'size': [np.float64(1183.1),
#    np.float64(154.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(26691019.944000006)},
#  {'code': 's1584',
#   'size': [np.float64(1325.7),
#    np.float64(800.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(7211808.000000012)},
#  {'code': 's1585',
#   'size': [np.float64(1325.7), np.float64(200.4), np.float64(139.6)],
#   'volume': np.float64(37087571.088)},
#  {'code': 's1587',
#   'size': [np.float64(1183.1),
#    np.float64(441.9),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(3555120.8520000055)},
#  {'code': 's1588',
#   'size': [np.float64(1183.1),
#    np.float64(154.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(26691019.944000006)},
#  {'code': 's1590',
#   'size': [np.float64(1767.6),
#    np.float64(599.6),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(7207000.128000012)},
#  {'code': 's1591',
#   'size': [np.float64(102.40000000000009),
#    np.float64(599.6),
#    np.float64(146.4)],
#   'volume': np.float64(8988819.45600001)},
#  {'code': 's1589',
#   'size': [np.float64(1870.0), np.float64(200.4), np.float64(146.4)],
#   'volume': np.float64(54863107.2)},
#  {'code': 's1592',
#   'size': [np.float64(1723.6),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(6985406.080000011)},
#  {'code': 's1594',
#   'size': [np.float64(1183.1),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(25451273.116)},
#  {'code': 's1596',
#   'size': [np.float64(1723.6),
#    np.float64(441.9),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(5179280.112000008)},
#  {'code': 's1597',
#   'size': [np.float64(540.5), np.float64(441.9), np.float64(139.6)],
#   'volume': np.float64(33343034.219999995)},
#  {'code': 's1595',
#   'size': [np.float64(1723.6),
#    np.float64(154.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(38884829.664000005)},
#  {'code': 's1598',
#   'size': [np.float64(1723.6),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(6985406.080000011)},
#  {'code': 's1600',
#   'size': [np.float64(1183.1),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(25451273.116)},
#  {'code': 's1601',
#   'size': [np.float64(1870.0),
#    np.float64(800.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(10172800.000000017)},
#  {'code': 's1602',
#   'size': [np.float64(102.40000000000009),
#    np.float64(800.0),
#    np.float64(139.6)],
#   'volume': np.float64(11436032.00000001)},
#  {'code': 's1603',
#   'size': [np.float64(1767.6), np.float64(200.4), np.float64(139.6)],
#   'volume': np.float64(49450094.783999994)},
#  {'code': 's1606',
#   'size': [np.float64(103.40000000000009),
#    np.float64(441.9),
#    np.float64(139.6)],
#   'volume': np.float64(6378667.416000005)},
#  {'code': 's1604',
#   'size': [np.float64(1870.0),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(7578736.000000013)},
#  {'code': 's1605',
#   'size': [np.float64(1870.0),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(40228113.2)},
#  {'code': 's1607',
#   'size': [np.float64(1870.0),
#    np.float64(596.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(7578736.000000013)},
#  {'code': 's1608',
#   'size': [np.float64(103.40000000000009),
#    np.float64(596.0),
#    np.float64(139.6)],
#   'volume': np.float64(8603045.440000007)},
#  {'code': 's1609',
#   'size': [np.float64(1766.6),
#    np.float64(154.10000000000002),
#    np.float64(139.6)],
#   'volume': np.float64(38003735.176)},
#  {'code': 's1611',
#   'size': [np.float64(1870.0),
#    np.float64(599.6),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(7624513.600000013)},
#  {'code': 's1612',
#   'size': [np.float64(102.40000000000009),
#    np.float64(599.6),
#    np.float64(139.6)],
#   'volume': np.float64(8571305.984000009)},
#  {'code': 's1610',
#   'size': [np.float64(1870.0), np.float64(200.4), np.float64(146.4)],
#   'volume': np.float64(54863107.2)},
#  {'code': 's1614',
#   'size': [np.float64(1325.7),
#    np.float64(599.6),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(5405250.096000009)},
#  {'code': 's1613',
#   'size': [np.float64(1723.6), np.float64(200.4), np.float64(146.4)],
#   'volume': np.float64(50567942.016)},
#  {'code': 's1616',
#   'size': [np.float64(1723.6),
#    np.float64(800.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(9376384.000000015)},
#  {'code': 's1618',
#   'size': [np.float64(1325.7), np.float64(200.4), np.float64(139.6)],
#   'volume': np.float64(37087571.088)},
#  {'code': 's1620',
#   'size': [np.float64(1183.1),
#    np.float64(441.9),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(3555120.8520000055)},
#  {'code': 's1621',
#   'size': [np.float64(1183.1),
#    np.float64(154.10000000000002),
#    np.float64(146.4)],
#   'volume': np.float64(26691019.944000006)},
#  {'code': 's1624',
#   'size': [np.float64(1183.1),
#    np.float64(358.1),
#    np.float64(69.79999999999998)],
#   'volume': np.float64(29572034.07799999)},
#  {'code': 's1625',
#   'size': [np.float64(1723.6),
#    np.float64(800.0),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(9376384.000000015)},
#  {'code': 's1626',
#   'size': [np.float64(1723.6), np.float64(198.8), np.float64(139.6)],
#   'volume': np.float64(47834174.528)},
#  {'code': 's1629',
#   'size': [np.float64(1324.5),
#    np.float64(601.2),
#    np.float64(6.800000000000011)],
#   'volume': np.float64(5414767.920000009)},
#  {'code': 's1630',
#   'size': [np.float64(1324.5), np.float64(198.8), np.float64(146.4)],
#   'volume': np.float64(38548671.84)},
#  {'code': 's1633',
#   'size': [np.float64(92.5), np.float64(441.5), np.float64(349.0)],
#   'volume': np.float64(14252723.75)},
#  {'code': 's1636',
#   'size': [np.float64(1185.15),
#    np.float64(155.89999999999998),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(12896588.973000001)},
#  {'code': 's1639',
#   'size': [np.float64(1324.5),
#    np.float64(158.7),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14671830.870000003)},
#  {'code': 's1637',
#   'size': [np.float64(410.29999999999995),
#    np.float64(759.9),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(21762730.506)},
#  {'code': 's1642',
#   'size': [np.float64(100.89999999999986),
#    np.float64(441.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(3109405.0299999965)},
#  {'code': 's1640',
#   'size': [np.float64(1870.0),
#    np.float64(155.89999999999998),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(20349003.4)},
#  {'code': 's1645',
#   'size': [np.float64(410.29999999999995),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17217730.728)},
#  {'code': 's1644',
#   'size': [np.float64(1734.8),
#    np.float64(158.7),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(19216830.648)},
#  {'code': 's1648',
#   'size': [np.float64(334.64999999999986),
#    np.float64(441.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(10312808.654999997)},
#  {'code': 's1647',
#   'size': [np.float64(1519.8),
#    np.float64(155.89999999999998),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(16538190.035999998)},
#  {'code': 's1651',
#   'size': [np.float64(104.0),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(4364231.040000001)},
#  {'code': 's1650',
#   'size': [np.float64(1870.0),
#    np.float64(114.3),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14919121.800000003)},
#  {'code': 's1654',
#   'size': [np.float64(104.0),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(4364231.040000001)},
#  {'code': 's1653',
#   'size': [np.float64(1870.0),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(25948568.800000004)},
#  {'code': 's1657',
#   'size': [np.float64(104.0),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(4364231.040000001)},
#  {'code': 's1655',
#   'size': [np.float64(1870.0),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(25948568.800000004)},
#  {'code': 's1660',
#   'size': [np.float64(410.29999999999995),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17217730.728)},
#  {'code': 's1658',
#   'size': [np.float64(1734.8),
#    np.float64(158.7),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(19216830.648)},
#  {'code': 's1663',
#   'size': [np.float64(1324.5),
#    np.float64(158.7),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14671830.870000003)},
#  {'code': 's1661',
#   'size': [np.float64(410.29999999999995),
#    np.float64(759.9),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(21762730.506)},
#  {'code': 's1664',
#   'size': [np.float64(104.0),
#    np.float64(800.0),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(5807360.000000001)},
#  {'code': 's1666',
#   'size': [np.float64(1766.0),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(24505439.840000007)},
#  {'code': 's1669',
#   'size': [np.float64(413.70000000000005),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17360407.512000006)},
#  {'code': 's1668',
#   'size': [np.float64(1738.2),
#    np.float64(158.7),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(19254493.332000002)},
#  {'code': 's1672',
#   'size': [np.float64(410.29999999999995),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17217730.728)},
#  {'code': 's1671',
#   'size': [np.float64(1734.8),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(24072501.152000003)},
#  {'code': 's1675',
#   'size': [np.float64(1324.5),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(18379079.880000006)},
#  {'code': 's1673',
#   'size': [np.float64(413.70000000000005),
#    np.float64(800.0),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(23101008.000000007)},
#  {'code': 's1678',
#   'size': [np.float64(104.0),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(4364231.040000001)},
#  {'code': 's1676',
#   'size': [np.float64(1870.0),
#    np.float64(114.3),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14919121.800000003)},
#  {'code': 's1681',
#   'size': [np.float64(104.0),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(4364231.040000001)},
#  {'code': 's1679',
#   'size': [np.float64(1870.0),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(25948568.800000004)},
#  {'code': 's1684',
#   'size': [np.float64(334.64999999999986),
#    np.float64(441.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(10312808.654999997)},
#  {'code': 's1682',
#   'size': [np.float64(1519.8),
#    np.float64(155.89999999999998),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(16538190.035999998)},
#  {'code': 's1687',
#   'size': [np.float64(1324.5),
#    np.float64(114.3),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(10567046.430000002)},
#  {'code': 's1685',
#   'size': [np.float64(413.70000000000005),
#    np.float64(715.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(20660964.030000005)},
#  {'code': 's1690',
#   'size': [np.float64(1324.5),
#    np.float64(158.7),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14671830.870000003)},
#  {'code': 's1688',
#   'size': [np.float64(410.29999999999995),
#    np.float64(759.9),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(21762730.506)},
#  {'code': 's1693',
#   'size': [np.float64(413.70000000000005),
#    np.float64(601.2),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17360407.512000006)},
#  {'code': 's1691',
#   'size': [np.float64(1738.2),
#    np.float64(198.8),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(24119680.368000004)},
#  {'code': 's1694',
#   'size': [np.float64(1519.8),
#    np.float64(155.89999999999998),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(16538190.035999998)},
#  {'code': 's1699',
#   'size': [np.float64(1324.8),
#    np.float64(159.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14749130.880000003)},
#  {'code': 's1698',
#   'size': [np.float64(410.0),
#    np.float64(759.9),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(21746818.200000003)},
#  {'code': 's1702',
#   'size': [np.float64(554.45),
#    np.float64(441.6),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17090189.376000006)},
#  {'code': 's1700',
#   'size': [np.float64(1738.2),
#    np.float64(155.79999999999995),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(18902646.888)},
#  {'code': 's1705',
#   'size': [np.float64(410.0),
#    np.float64(600.4),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(17182247.200000003)},
#  {'code': 's1703',
#   'size': [np.float64(1734.8),
#    np.float64(159.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(19313701.880000003)},
#  {'code': 's1708',
#   'size': [np.float64(195.0),
#    np.float64(600.4),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(8172044.400000001)},
#  {'code': 's1706',
#   'size': [np.float64(1519.8),
#    np.float64(115.1),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(12210042.804000001)},
#  {'code': 's1711',
#   'size': [np.float64(1183.75),
#    np.float64(155.79999999999995),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(12873091.849999998)},
#  {'code': 's1709',
#   'size': [np.float64(336.04999999999995),
#    np.float64(597.4),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14012787.646)},
#  {'code': 's1714',
#   'size': [np.float64(336.04999999999995),
#    np.float64(441.6),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(10358297.664)},
#  {'code': 's1712',
#   'size': [np.float64(1519.8),
#    np.float64(155.79999999999995),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(16527581.831999999)},
#  {'code': 's1717',
#   'size': [np.float64(1324.8),
#    np.float64(159.5),
#    np.float64(69.80000000000001)],
#   'volume': np.float64(14749130.880000003)},
#  ...]

# %%
# draw the scrap of a block
block_num = 2
helper.all_big_blocks[block_num].draw_it(True)

# %%
# draw the filling of a block
block_num = 2
helper.all_big_blocks[block_num].draw_it()
